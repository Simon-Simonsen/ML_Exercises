# %% [markdown]
# <b>Machine Learning Exercise session: 26 and 28 August 2025</b>

# %% [markdown]
# ## Welcome to Machine Learning!
# We hope you will have a great time and learn a lot taking this course :)
# Since the course material assumes familiarity with Python and data science libraries such as numpy, pandas, matplotlib and scipy, this exercise session is meant as a refresher of some commonly used functionality in these libraries.
# Don't be intimidated by the size of this exercise sheet! You are not expected to complete it during the exercise sessions, feel free to take your time and review the sections you are interested in.
#
# ⚠️ **This notebook will not go through a recap of Python programming, so please refer to the material from the "Introduction to Data Science and Programming" course or online tutorials such as https://www.learnpython.org/**

# %% [markdown]
# ## Part 1: Setup & Installations 🛠️

# %% [markdown]
# ## Create a virtual environment for the machine learning course

# %% [markdown]
# ### Why virtual environments
# Helps avoid dependency issues between packages. You are using a package manager such as pip or conda, but ocassionally you can run into the situation of no possible combination of package versions being compatible. Additionally, sometimes errors can later occur despite the package manager initially allowing the installation, which are very hard to debug and fix.
#
# ### Don't do everything in base
# Yes, you can go on a long time just installing everything in base without any issues. But with so many different packages, problems are bound to occur sooner or later. Additionally, virtual environments help keep the installations for your different project organised.
#
# ### Let's create a virtual environment for the machine learning course!

# %% [markdown]
# -----

# %% [markdown]
# ### Step 1: Create virtual environment and activate it

# %% [markdown]
# Navigate to the directory of this exercise and run the following commands in your terminal (if you have trouble running these you can also try running them in the anaconda prompt if you did your python setup using anaconda):

# %% [markdown]
# **conda create -n ml --file requirements.txt**
# **conda activate ml**

# %% [markdown]
# **Note**: here, "ml" is the name of the virtual environment and how you will refer to it later.
# Feel free to change it to whatever you see fit!

# %% [markdown]
# **Note 2**: by specifying the requirements file with the "--file" parameter, the packages specified in the requirements file will be installed when creating the environment (as well as any dependencies they need). In the same folder as this notebook, you will find the requirements file **requirements.txt** which contains all the packages needed for this exercise, as well as some machine learning libraries that will be used in this course.

# %% [markdown]
# **The provided requirements.txt was tested with Python version 3.13.5 -- If you run the above command, this version should be installed automatically, but this may be useful for debugging purposes**

# %% [markdown]
# ### Step 2: Install necessary packages

# %% [markdown]
# ### How to install a package with conda / pip

# %% [markdown]
# All the packages required for this exercise are in the provided **requirements.txt** file and should be automatically installed if you ran the above command to create the virtual environment. However, we will go through a quick recap of how to install any additional packages.
# To install a package, you can run **conda install package_name** (where you specify the name of the package instead of package_name). Note that sometimes conda will not find a package, but pip will, and vice versa, so it is worth trying to install with another package manager if one of them doesn't find the package. To install a package with pip run **pip install package_name**

# %% [markdown]
# ### Step 3 (Optional): Install the course book library

# %% [markdown]
# The main course book used in the course, "An Introduction to Statistical Learning with Applications in Python" has its own python library which will be necessary in order to follow some of the examples and exercises in the book. You can install the library with pip:

# %% [markdown]
# **pip install islp**

# %% [markdown]
# The documentation for the package can be found here: https://intro-stat-learning.github.io/ISLP/
# Some of the datasets used in the book can also be found on the book's website: https://www.statlearning.com/resources-python

# %% [markdown]
# ### Step 4: Use the virtual environment in a Jupyter notebook

# %% [markdown]
# To be able to use the newly created virtual environment in a jupyter notebook, run the following in your terminal (while you have the newly created virtual environment activated):

# %% [markdown]
# **ipython kernel install --user --name=ml**

# %% [markdown]
# You should now be able to create a notebook in the new "ml" environment, as well as change an existing notebook to the "ml" environment at any time:

# %% [markdown]
# **How it looks in Jupyter notebook**

# %% [markdown]
# ![jupyter_kernel.png](attachment:jupyter_kernel.png)

# %% [markdown]
# ![change_kernel.png](attachment:change_kernel.png)

# %% [markdown]
# **How it looks in VScode + Jupyter notebook**
# Please note that in order to use Jupyter notebooks in VScode you need to have the Jupyter extension installed (see screenshot below)

# %% [markdown]
# ![extension.png](attachment:extension.png)

# %% [markdown]
# On the top left of the opened file you should see this symbol, click it

# %% [markdown]
# ![vscode_kernel_1.png](attachment:vscode_kernel_1.png)

# %% [markdown]
# On the top center of the screen you will see the option to "Select another kernel", select that and then choose "Jupyter kernel". After this you should be able to select the environment you created in the list that appears.

# %% [markdown]
# ![vscode_kernel_3.png](attachment:vscode_kernel_3.png)

# %% [markdown]
# ![vscode_kernel_2.png](attachment:vscode_kernel_2.png)

# %% [markdown]
# ![vscode_kernel_4.png](attachment:vscode_kernel_4.png)

# %% [markdown]
# ### Step 5: Check imports are working

# %% [markdown]
# In order to check that the instalations were successful, please run the cell below:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# If this cell ran with no errors, you are ready to start this exercise :)
# If you encounter any issues, we are happy to help you during exercise sessions, and you can also ask for help during StudyLab.

# %% [markdown]
# ## Part 2: NumPy recap

# %% [markdown]
# ### NumPy documentation & tutorials

# %% [markdown]
# It's a good idea to check out the NumPy official documentation. Here you will find a comprehensive overview of all the functionality available in the library, as well as code examples and tutorials. When using some functionality from a library such as NumPy, it is always a good idea to check out the official documentation to find out what options are available to you. (such as parameters in a function or other functionality from the library that could help with your problem)
# **Code documentation**: https://numpy.org/doc/stable/reference/index.html#reference
# **Useful tutorials**: https://numpy.org/doc/stable/user/quickstart.html

# %% [markdown]
# ### 2.1: Commonly used functions

# %% [markdown]
# ### Array creation

# %% [markdown]
# - a) Create a size 10 array of 0s
# - b) Create a numpy array from the given Python list
# - c) Create a numpy array containing the numbers from 1 to 10

# %% [markdown]
# **Useful documentation**
# - https://numpy.org/doc/stable/reference/generated/numpy.zeros.html
# - https://numpy.org/doc/stable/reference/generated/numpy.array.html
# - https://numpy.org/doc/stable/reference/generated/numpy.arange.html

# %%
lst = [5,6,8]

# %%
# Your solution here...
np.array(range(10))
np.zeros(10)
np.array(lst)
# Out:
# array([5, 6, 8])

# %% [markdown]
# ### Array dimensions and slicing

# %% [markdown]
# - a) Check the dimensions of the given array
# - b) Print the second element on the first row
# - c) Print the third column
# - d) Print the second row

# %% [markdown]
# **Useful documentation**
# - https://numpy.org/doc/stable/reference/generated/numpy.ndarray.shape.html

# %%
arr = np.array([[0,2,3],
                [4,4,6]])

# %%
# Your solution here...
np.shape(arr)
arr[0][1]
arr[:,2]
arr[1,:]
# Out:
# array([4, 4, 6])

# %% [markdown]
# ### Descriptive statistics

# %% [markdown]
# - Find the maximum value from the given array
# - Find the minimum value
# - Find the mean and standard deviation to 3 decimal places

# %% [markdown]
# **Useful documentation**
# - https://numpy.org/doc/stable/reference/generated/numpy.max.html
# - https://numpy.org/doc/stable/reference/generated/numpy.min.html
# - https://numpy.org/doc/stable/reference/generated/numpy.mean.html
# - https://numpy.org/doc/stable/reference/generated/numpy.std.html
# - https://numpy.org/doc/stable/reference/generated/numpy.round.html

# %%
arr2 = np.array([2,3,4,8,9,10,2])

# %%
round(arr2.mean(),3)
round(arr2.std(),3)
min(arr2)
max(arr2)
# Out:
# np.int64(10)

# %% [markdown]
# **Extra exercise**
# How do you expect these functions to behave if you have a matrix instead of a 1d array?
# Run the code below to test:

# %%
# reusing matrix from previous exercise
arr = np.array([[0,2,3],
                [4,4,6]])

# Your solution here...

# %% [markdown]
# ### Index of the highest or lowest value in an array

# %% [markdown]
# - a) Find the index of the highest value in the given array
# - b) Find the index of the lowest value in the given array

# %% [markdown]
# **Useful documentation**
# - https://numpy.org/doc/stable/reference/generated/numpy.argmax.html
# - https://numpy.org/doc/stable/reference/generated/numpy.argmin.html

# %% [markdown]
# You will be finding the index of the highest value in an array a lot in machine learning when predicting labels. The model outputs probabilities for all the possible classes, and then you select the one with the highest probability as its prediction.

# %%
arr3 = np.array([0.3, 0.5, 0.2])

# %%
np.argmax(arr3) # 1
np.argmin(arr3) # 2
# Out:
# np.int64(2)

# %% [markdown]
# ### Uniques and value counts

# %% [markdown]
# - a) Find what unique values appear in the following array
# - b) Find the counts of all unique values
# - c) Find the most common value

# %% [markdown]
# **Useful documentation**
# - https://numpy.org/doc/stable/reference/generated/numpy.unique.html

# %%
arr4 = np.array([4,4,3,7,9,9,7,7,7,0,9])

# %%
# Your solution here...
uniq, count = np.unique(arr4, return_counts=True)
uniq[np.argmax(count)] # 7
# Out:
# np.int64(7)

# %% [markdown]
# ### 2.2 Filtering

# %% [markdown]
# ### Sorting

# %% [markdown]
# - a) Sort the given array in ascending order
# - b) Sort the array in descending order

# %% [markdown]
# **Useful documentation**
# - https://numpy.org/doc/stable/reference/generated/numpy.sort.html
# - https://numpy.org/doc/stable/reference/generated/numpy.ndarray.sort.html

# %% [markdown]
# Two sort functions exist, np.sort(arr), which is passed the numpy array, and returns a sorted copy of the original array, and np.ndarray.sort() which is called on the numpy array object and sorts the array in-place (changing the original array).
#
# **Extra exercise**
# What do you expect the original array value and the returned value to be after using np.sort()? What about np.ndarray.sort()?
# Try solving this exercise by both methods.

# %%
# reusing array from previous exercise
arr4 = np.array([4,4,3,7,9,9,7,7,7,0,9])

# %%
# Your solution here...
np.sort(arr4)
np.sort(arr4)[::-1]
# Out:
# array([9, 9, 9, 7, 7, 7, 7, 4, 4, 3, 0])

# %% [markdown]
# ### Filter based on condition

# %% [markdown]
# - a) Print all the values bigger than 5.0 in the given array
# - b) Print all the values smaller than 3.5
# - c) Print all the values betwen 2.5 and 7.5 (inclusive)
# - d) Print all the values smaller than 1.0 or bigger than 9.0

# %% [markdown]
# **Useful resources**
# A Medium post that explains filtering in numpy really well
# ( the first few lines of the article are promoting his own course, not endorsing it and skip that, but the tutorial after is really helpful :) )
# - https://medium.com/@amit25173/what-is-a-numpy-mask-and-why-use-it-cb567e77fb7f

# %%
arr5 = np.array([[1.5, 3.2, 8.9, 1.0],
                 [3.0, 2.5, 1.5, 0.3],
                 [8.8, 7.4, 6.3, 9.2]])

# %%
# Your solution here...
five_mask = arr5 > 5.0
three_mask = arr5 < 3.5
between_mask = ((arr5 >= 2.5) & (arr5 <=7.5))
below_mask = ((arr5< 1.0) & (arr5>=9.0))
arr5[five_mask], arr5[three_mask], arr5[between_mask], arr5[below_mask]
# Out:
# (array([8.9, 8.8, 7.4, 6.3, 9.2]),
#  array([1.5, 3.2, 1. , 3. , 2.5, 1.5, 0.3]),
#  array([3.2, 3. , 2.5, 7.4, 6.3]),
#  array([], dtype=float64))

# %% [markdown]
# ## Part 3: Pandas recap

# %% [markdown]
# For the rest of our exercises, we'll be using the Marvel dataset, containing information about characters in the Marvel cinematic universe.<br>
# Here is a short description of the columns we'll be working with today:<br>
# - **Name** : Name of the character (sometimes containing both the superhero name and the everyday name of a character)
# - **SEX** : Gender of character
# - **APPERANCES** : Number of times the character has appeared in Marvel movies
# - **Year** : Year when character was first introduced

# %% [markdown]
# ### Reading data

# %% [markdown]
# - Read in the data from the file **marvel-wikia-data.csv** as a Pandas dataframe
# - How would you read in data from a file separated by a different character other than ","? (for example, a tab separated file)

# %% [markdown]
# **Useful documentation**
# - https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
# Your solution here...
df = pd.read_csv("/Users/simonbruun-simonsen/Desktop/ML_Exercises/ML_Exercises/Week1_exercises/marvel-wikia-data.csv")
#To read it different than with commaseperator you will have to change the delimiter in the function.
#The default is comma.

# %% [markdown]
# ### Inspecting the data

# %% [markdown]
# - a) Print the first five rows of the dataset
# - b) Print the number of rows and columns in the dataset
# - c) Print the names of the columns
# - d) Print the data type of each column
# - e) Is there missing data in any of the columns we'll be working with? If so which ones

# %% [markdown]
# **Useful documentation**
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.columns.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html

# %%
# Your solution here...
df.head(5) #Prints first 5 rows.
df.shape #Will give us 16376, 13. With 16376 rows and 13 columns.
df.columns # Will give us the column names, not the variable type for each.
df.info(verbose=False)
df.isna().sum() # will give us the sum of NAN values in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16376 entries, 0 to 16375
# Columns: 13 entries, page_id to Year
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.6+ MB
# page_id                 0
# name                    0
# urlslug                 0
# ID                   3770
# ALIGN                2812
# EYE                  9767
# HAIR                 4264
# SEX                   854
# GSM                 16286
# ALIVE                   3
# APPEARANCES          1096
# FIRST APPEARANCE      815
# Year                  815
# dtype: int64

# %% [markdown]
# ### Cleaning the data

# %% [markdown]
# - a) Create a dataframe containing only the "Year" and "APPEARANCES" columns and remove any rows with missing values
# - b) Create a dataframe containing only the "SEX" column and remove any rows with missing values
#
# We will use these dataframes later for plotting exercises!

# %% [markdown]
# **Useful documentation**
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html

# %% [markdown]
# ### ⚠️ A warning about copy vs reference in pandas
# When you create a dataframe based on another dataframe, such as by filtering which rows to select or by only selecting some columns, it is a **reference** to the original dataframe. This means that any changes you make to one dataframe also apply to the other.
# If you intend to modify the dataframe you are creating, it is the best if you specify **.copy()** to ensure that it is an actual copy of the original dataframe and not a reference, so any changes you make do not also apply to the original dataframe.

# %%
# Your solution here...
df2 = df.copy()
df_year_appear = df2[["Year", "APPEARANCES"]]
df_year_appear= df_year_appear.dropna()
df_sex = df2["SEX"].dropna()

# %% [markdown]
# ### Filtering

# %% [markdown]
# **For these exercises, use the original dataframe you read from the file and not the earlier created ones**
# - a) How many characters were introduced between 1960 and 1965 (inclusive)?
#     - **Extra exercise**: Try also filtering the year and appearances dataframe you made in the previous exercise. Do you get the same number? Why / why not?
# - b) How many characters appeared over 1000 times in Marvel movies?
# - c) How many characters have hazel eyes and brown hair?
# - d) Are there more alive or dead characters in the Marvel universe?
# - e) The number of alive and dead characters doesn't sum up to the total number of characters. Why is that?

# %% [markdown]
# **Useful resources**
# - https://pandas.pydata.org/docs/user_guide/indexing.html#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html
#
# A tutorial on filtering in pandas
# - https://www.geeksforgeeks.org/pandas/ways-to-filter-pandas-dataframe-by-column-values/

# %%
# Your solution here...
character_count = ((df["Year"]>=1960) & (df["Year"]<=1965))
character_count.sum()
over_thousand = df["APPEARANCES"] > 1000
over_thousand.sum()
hazel_brown = ((df["EYE"] == "Hazel Eyes") & (df["HAIR"] == "Brown Hair") )
hazel_brown.sum() #35 Using sum we count all Trues(1) or add it up, but since false is 0 they dont appear.
#For e, it might be because of na values. Removing na values we might get it to be more correct. But this might be because
#of how they choose to determine whether a character is dead or alive.
# Out:
# np.int64(35)

# %% [markdown]
# ## Part 4: matplotlib recap

# %% [markdown]
# **For the following exercises, use the 2 dataframes you created in the Cleaning section of the pandas exercises.**

# %% [markdown]
# ### Commonly used plots

# %% [markdown]
# ### Histogram

# %% [markdown]
# Let's look at how gender is distributed in the marvel cinematic universe.
# - Create a histogram of character genders in the Marvel universe
# - Make the plot nice and readable:
#     - Add a title
#     - Add axis titles
#     - Shorten the names of the x axis labels so that they don't overlap
#     - Make the bars your favorite color

# %% [markdown]
# **Useful documentation**
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xticks.html
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html

# %%
# Your solution here...
count = df["SEX"].value_counts()

plt.bar(count.index,count.values, color = ["Blue","Green","Red","Pink"])
plt.xticks(rotation=45)
plt.xlabel("Genders")
plt.ylabel("Count")
plt.legend()
plt.title("count of genders")
# Out:
# /var/folders/q8/ztn6c_nj7mz53t10363qj1600000gn/T/ipykernel_88227/1413877884.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0.5, 1.0, 'count of genders')

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# Let's look at the relationship between the year when a Marvel character was introduced and how many appearances they've had.<br>
# What do we expect to see?
# - Make a scatter plot of the year and appearances columns - plot appearances on the x axis and the year on the y axis
# - Make the plot nice and readable:
#     - Add a title
#     - Add axis titles
#     - Make the plot your favorite color

# %%
# Your solution here...
df_year_appear["APPEARANCES"]
df_year_appear["APPEARANCES"]
plt.scatter(df_year_appear["APPEARANCES"], df_year_appear["Year"], color = "Red")
plt.xlabel("Apperances")
plt.ylabel("Introduced")
plt.title("Appearance vs Introduction")
# Out:
# Text(0.5, 1.0, 'Appearance vs Introduction')

# %% [markdown]
# **Extra exercise**: Take a moment to interpret the plot. Do you notice any interesting patterns?

# %% [markdown]
# ### Line plot

# %% [markdown]
# For this exercise, use the below provided data.
# - Plot x and y0 using a line plot
# - Plot x and y1 using a line plot in the same figure
# - Make the plot nice and readable:
#     - Add a title
#     - Add axis titles
#     - Make the lines thicker
#     - Add a legend

# %%
# Generate data for each plot
x = list(range(10))
y0, y1 = list(np.arange(10)*8), list(np.arange(10)**2)

# %%
# Your solution here...
fig, ax = plt.subplots(figsize=(10,6))

ax.plot(x,y0, color="Green", label="x vs y0")
ax.plot(x,y1, color="Red", label = "x vs y1")
ax.set_xlabel("x_Value")
ax.set_ylabel("y_Value")
ax.set_title("x vs y")
ax.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Part 5: Scikit-learn recap

# %% [markdown]
# Scikit-learn is a Python library which provides functionality for machine learning tasks such as Regression and Classification, as well as preprocessing functions and datasets. You will get to experiment with this library a lot during this course, but for this small recap we will use some functions that you have most likely seen before during your first year project.
# If you created the virtual environment using the tutorial in this notebook, you should already have scikit-learn installed. Otherwise, you can always install it by running **conda install scikit-learn**

# %% [markdown]
# ### Loading datasets
# Scikit-learn provides a few datasets, as well as functions to generate synthetic data. You can see all the datasets and functions provided for this purpose here: https://scikit-learn.org/stable/api/sklearn.datasets.html

# %% [markdown]
# - Load the "diabetes" dataset using scikit-learn
# - Save the features to a variable named "X" and the target values to a variable named "y"
# - Read the documentation of the dataset to see what all the values represent
#
# **Useful documentation**
# - https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_diabetes.html#sklearn.datasets.load_diabetes
# - https://scikit-learn.org/stable/datasets/toy_dataset.html#diabetes-dataset (dataset documentation)

# %%
from sklearn.datasets import load_diabetes

# %%
# Your solution here...
data = load_diabetes()
X = data["data"]
Y = data["target"]

# %% [markdown]
# ### Train-test split
# In machine learning, we usually split the original dataset into two datasets, one used for training and one used for testing (sometimes even into three, but you will learn about that soon!). The training dataset is used for optimizing the machine learning model, while the test dataset is used to estimate its performance on new, unseen data.
# Scikit-learn provides functionality for splitting the dataset according to your needs.

# %% [markdown]
# - Split the diabetes dataset into a train and test set
#     - Use 80% of the data for training and 20% for testing
#     - Set a seed for reproducibility (**Extra exercise**: Read the documentation and see what the parameters of this function do and what their default values are. Why does it make sense to set a seed when using this function?)
# - Print the shapes of the original X and y variables you created in the previous exercise, then the shapes of the resulting variables after splitting the dataset into train and test
#
# **Useful documentation**
# - https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
from sklearn.model_selection import train_test_split

# %%
# Your solution here...
X_train, X_test, y_train, y_test = train_test_split( X,Y, test_size=0.20, random_state=42)

# %% [markdown]
# ### Linear Regression
# You will learn a lot about linear regression in the upcoming weeks, but let's use linear regression as an example of how to fit and evaluate a model using scikit-learn.
# - Fit a linear regression model on the training dataset
# - Print the coefficients and intercept of the model
# - Predict the target values of the test dataset using the model you obtained
# - Calculate the $R^2$ of the predictions
# - **Extra exercise**: We just constructed a linear regression model which uses all 10 features available to us. Read the dataset documentation and see if you can construct a linear regression model with similar (or better) performance using a different set of features!
#
# **Useful documentation**
# - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
# Your solution here...
reg = LinearRegression().fit(X_train,y_train)
print("Coefficient ", reg.coef_, "Intercept: ", reg.intercept_ )
y_pred = reg.predict(X_test)
r2score = r2_score(y_test,y_pred)
print(r2score)
# Out:
# Coefficient  [  37.90402135 -241.96436231  542.42875852  347.70384391 -931.48884588
#   518.06227698  163.41998299  275.31790158  736.1988589    48.67065743] Intercept:  151.34560453985995
# 0.45260276297191937

# %% [markdown]
# ## Machine learning "in the real world"

# %% [markdown]
# Firstly, congratulations for making it to the end of this notebook! That was a long recap, and we hope it was helpful :)
# Studying machine learning can be difficult, and sometimes it's hard to remember that outside all the linear algebra, statistics and calculus there's so many practical applications and possibilities to apply this technology to whatever **you** find interesting...
#
# Here are some examples of practical applications in which fellow ITU Data Science students applied ML (bsc thesis and personal projects of students)
# - Using computer vision to classify fish species in underwater environments
# - Exploring the importance of clinical features in ML models predicting pleural effusion (fluid build-up in the lungs)
# - AI coach for a videogame (League of Legends) that can answer specific questions about the game and analyse a given game file for feedback
# - Analysing brain graph representations learned by graph neural networks
# - Predicting emotions based on personality traits and experiment information using XGBoost
# - Extracting information from large text corpuses using ML and network analysis to answer sociopolitical questions
# - Predicting emotions on facial images on infants, based on unit facial movement using support vector machines and convolutional neural networks
#
# These are all projects that ITU students successfully implemented using the knowledge from this degree, including this course. Putting in the extra effort now is worth it, and you will soon be equipped to work on ML projects that you find interesting as well!

# %% [markdown]
# ## Extra exercises and other useful libraries

# %% [markdown]
# ### Book Python intro
# The main course book used in the course, "An Introduction to Statistical Learning with Applications in Python", also has an introduction to Python, numpy, pandas and matplotlib starting at page 40. Feel free to follow along the introduction, and try out the practical exercises at the end of the chapter for some extra hands-on experience!
#
# ### Python tutorials
#
# Python official tutorial
# - https://docs.python.org/3/tutorial/
#
# ### Numpy tutorials
#
# A very well explained and comprehensive beginner numpy tutorial
# - https://numpy.org/doc/stable/user/absolute_beginners.html
#
# ### Scipy
# Scipy is another popular scientific computing Python library. For this course, the scipy.linalg and scipy.stats modules might come in useful.
# Scipy.stats implements statistics functionality you might find useful, such as hypothesis tests and probability distributions.
# Scipy.lingalg implements more linear algebra functionality than numpy's linalg module, so occassionally you might find it more convenient to import some functionality from scipy rather than implement it yourself only using numpy.
#
# - Scipy.linalg intro (more explanations) : https://docs.scipy.org/doc/scipy/tutorial/linalg.html
# - Scipy.linalg documentation (code reference) :https://docs.scipy.org/doc/scipy/reference/linalg.html
# - Scipy.stats intro (more explanations) : https://docs.scipy.org/doc/scipy/tutorial/stats.html
# - Scipy.stats documentation (code reference) :https://docs.scipy.org/doc/scipy/reference/stats.html
